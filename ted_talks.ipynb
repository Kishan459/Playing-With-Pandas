# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishan459/Playing-With-Pandas/blob/main/ted_talks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pycon-2019-tutorial/master/ted.csv')

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
df.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %%
df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %%
df['ratings'][0]
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
df['related_talks'][0].split("/")
# Out:
# ["[{'id': 865, 'hero': 'https:",
#  '',
#  'pe.tedcdn.com',
#  'images',
#  'ted',
#  "172559_800x600.jpg', 'speaker': 'Ken Robinson', 'title': 'Bring on the learning revolution!', 'duration': 1008, 'slug': 'sir_ken_robinson_bring_on_the_revolution', 'viewed_count': 7266103}, {'id': 1738, 'hero': 'https:",
#  '',
#  'pe.tedcdn.com',
#  'images',
#  'ted',
#  'de98b161ad1434910ff4b56c89de71af04b8b873_1600x1200.jpg\', \'speaker\': \'Ken Robinson\', \'title\': "How to escape education\'s death valley", \'duration\': 1151, \'slug\': \'ken_robinson_how_to_escape_education_s_death_valley\', \'viewed_count\': 6657572}, {\'id\': 2276, \'hero\': \'https:',
#  '',
#  'pe.tedcdn.com',
#  'images',
#  'ted',
# ...

# %%
df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %% [markdown]
# ## find top 5 ted talk which provoked the most oneline discussion

# %%
df.sort_values(by='comments').tail()
# Out:
#       comments                                        description  duration  \
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
#
#         event   film_date  languages       main_speaker  \
# 1787  TED2014  1395100800         33     David Chalmers
# 201   TED2008  1204070400         49  Jill Bolte Taylor
# 644   TED2010  1265846400         39         Sam Harris
# 0     TED2006  1140825600         60       Ken Robinson
# 96    TED2002  1012608000         42    Richard Dawkins
#
#                                                    name  num_speaker  \
# 1787  David Chalmers: How do you explain consciousness?            1
# ...

# %% [markdown]
# #### there is a problem with this approch because there are some videos which might be there for years and contains more comments then the new one so what we do is we will make a new feature view per comment by dividing views with comments

# %%
df['views_per_comments'] = df.views / df.comments

# %%
df.sort_values('views_per_comments').head().reset_index()
# Out:
#    index  comments                                        description  \
# 0    744       649  Hours before New York lawmakers rejected a key...
# 1    803       834  David Bismark demos a new system for voting th...
# 2     96      6404  Richard Dawkins urges all atheists to openly s...
# 3    694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...
# 4    954      2492  Janet Echelman found her true voice as an arti...
#
#    duration                  event   film_date  languages  \
# 0       453  New York State Senate  1259712000          0
# 1       422         TEDGlobal 2010  1279065600         36
# 2      1750                TED2002  1012608000         42
# 3       489                TED2010  1265760000         32
# 4       566                TED2011  1299110400         35
#
#             main_speaker                                               name  \
# 0        Diane J. Savino    Diane J. Savino: The case for same-sex marriage
# ...

# %% [markdown]
# ## top 5 ted talk which provoked the most oneline discussion

# %%
df.sort_values('views_per_comments')['title'].head().reset_index()
# Out:
#    index                                title
# 0    744       The case for same-sex marriage
# 1    803               E-voting without fraud
# 2     96                     Militant atheism
# 3    694  Inside a school for suicide bombers
# 4    954         Taking imagination seriously

# %% [markdown]
# ## visualize the distribution of comments

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df[df['comments']<1000]['comments'].plot(kind='hist',bins=20)

# %%
df.shape
# Out:
# (2550, 18)

# %%
df[df.comments >= 1000].shape
# Out:
# (32, 18)

# %% [markdown]
# #### lossing only 32 observations from 2550 by filtering comments less then 1000 because now it is making more sense then earlier

# %%
df.query('comments < 1000').comments.plot(kind='hist',bins=20)

# %%
df.loc[df.comments < 1000 , 'comments'].plot(kind='hist',bins=20)

# %% [markdown]
# ####comments between 50 to 100 are more frequent

# %% [markdown]
# #plot the number of talk that took place each year

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df['film_datetime'] = pd.to_datetime(df['film_date'],unit='s')

# %%
plt.figure(figsize=(15,7))
df['film_datetime'].dt.year.value_counts().sort_index().plot()

# %%
df['film_datetime'].max()
# Out:
# Timestamp('2017-08-27 00:00:00')

# %% [markdown]
# # what were the best events in TED history to attend?

# %%
df.sample(5)
# Out:
#       comments                                        description  duration  \
# 662        117  Photographs do more than document history -- t...       362
# 570         64  India's revolutionary Aravind Eye Care System ...      1047
# 1725       182  Astronomers believe that every star in the gal...       398
# 259        229  Why do we crave love so much, even to the poin...       956
# 630        197  James Cameron's big-budget (and even bigger-gr...      1028
#
#               event   film_date  languages        main_speaker  \
# 662         TED2010  1265846400         36      Jonathan Klein
# 570   TEDIndia 2009  1257379200         22  Thulasiraj Ravilla
# 1725        TED2014  1395187200         28       Jeremy Kasdin
# 259         TED2008  1201910400         33        Helen Fisher
# 630         TED2010  1265932800         36       James Cameron
#
#                                                    name  num_speaker  \
# ...

# %%
df['ratings'][0]
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
df.groupby('event')['views'].agg(['count','mean']).reset_index().sort_values(by='count',ascending=False)
# Out:
#                       event  count          mean
# 64                  TED2014     84  2.072874e+06
# 59                  TED2009     83  1.754896e+06
# 63                  TED2013     77  2.302700e+06
# 66                  TED2016     77  1.812622e+06
# 65                  TED2015     75  2.011017e+06
# ..                      ...    ...           ...
# 200              TEDxEQChCh      1  2.829484e+06
# 202             TEDxEastEnd      1  1.811102e+06
# 203            TEDxEdmonton      1  1.579033e+06
# 204              TEDxEuston      1  1.318454e+06
# 354  World Science Festival      1  3.302312e+06
#
# [355 rows x 3 columns]

# %%
df.groupby('event')['views'].agg(['count','mean','sum']).reset_index().sort_values(by='sum',ascending=False)
# Out:
#                       event  count          mean        sum
# 63                  TED2013     77  2.302700e+06  177307937
# 64                  TED2014     84  2.072874e+06  174121423
# 100          TEDGlobal 2013     66  2.584163e+06  170554736
# 65                  TED2015     75  2.011017e+06  150826305
# 56                  TED2006     45  3.274345e+06  147345533
# ..                      ...    ...           ...        ...
# 258  TEDxNASA@SiliconValley      1  1.558950e+05     155895
# 0             AORN Congress      1  1.498180e+05     149818
# 337            TEDxWaterloo      1  1.388120e+05     138812
# 228               TEDxIslay      1  1.202740e+05     120274
# 350         The Do Lectures      1  1.123210e+05     112321
#
# [355 rows x 4 columns]

# %% [markdown]
# #### have to find the best event in histry of TED talk so i decided to do if by avarage views per talk but find out that some event have only one talk so there avarage will be high then i decided to do it by sum of the views per event and come to conclusion that TED2013 was the best event of TED talk history to attend because it has heighest no. of views ( people liked it the most) and has 77 talks.

# %% [markdown]
# #### there is two problem with above approch
# #### 1. older talks may get highest no. of views then the newer ones
# #### 2. there can be other resons for the heighest no. of views may be the some talks are ontroversial or bad that why people might be sharing or watching

# %% [markdown]
# # Unpacking the rating feature

# %%
import ast

# %%
ast.literal_eval(df['ratings'][0])
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
df['ratings_list'] = df['ratings'].apply(ast.literal_eval)

# %%
df['ratings_list'][0]
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
type(df['ratings_list'][0])
# Out:
# list
